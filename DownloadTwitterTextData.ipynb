# %%
from textblob import TextBlob
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime

# %%
consumerKey = "lol"
consumerSecret = "lol"
accessToken = "lol"
accessTokenSecret = "lol"

auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# demo/helper block

tweets = tweepy.Cursor(api.search, q="Align Technology", lang='en')

i = 0
example_status = None

for status in tweets.items():
    if i==1: break
    i += 1
    example_status = status
    print(example_status.text)
    print('\n')

example_status.__dict__['created_at']
# Out:
# Align Technology Inc. Shares Approach 52-Week High - Market Mover https://t.co/NgnSkKUCXe $ALGN #stockmarket #kwhenfinance
# datetime.datetime(2020, 12, 9, 8, 59, 43)

# %%
codes_names = {'ALGN': 'Align Technology',
               'AMP': 'Ameriprise Financial',
               'AON': 'Aon Plc',
               'BRK.B': 'CMCSA',
               'CMCSA': 'Comcast Corporation',
               'CMI': 'Cummins Inc',
               'CNP': 'CenterPoint Energy',
               'DG': 'Dollar General Corporation',
               'EXR': 'Extra Space Storage',
               'JKHY': 'Jack Henry Associates',
               'JPM': 'J.P. Morgan',
               'LHX': 'L3Harris Technologies'}

# %%
def collect_company_tweets(api, q, lang='en', save_path=None, until=None):
    tweets = tweepy.Cursor(api.search, q=q, lang=lang, until=until)
    
    collected_texts = pd.Series()
    for status in tweets.items():
        collected_texts[status.created_at] = status.text
        if status.created_at.strftime("%Y-%m-%d") == '2020-11-25': break
        
    collected_texts.to_csv(save_path+'/'+q+".csv")
    
    return collected_texts

ex=collect_company_tweets(api, 'J.P. Morgan', 
                          save_path="F:/Graduate/Lecture Notes and Homework/NLP",
                         until="2020-12-09")    
ex
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   after removing the cwd from sys.path.
# 2020-12-08 23:51:00    “The vaccine news and the focus on that is the...
# 2020-12-08 23:30:03    The J.P. Morgan Healthcare #Conference is goin...
# 2020-12-08 23:17:45    RT @NathaniNoShame: every night in fear that s...
# 2020-12-08 23:10:42    Alphabet Inc. (GOOG) surprised the market with...
# 2020-12-08 23:07:06    @TheSolariReport Millionaires don't use Astrol...
#                                              ...
# 2020-11-30 00:41:31    The Liquidating Team in play.\nFirst the manip...
# 2020-11-30 00:26:19                J P Morgan, Ghost of Rich Dude's Past
# 2020-11-29 23:42:38    Go as far as you can see; when you get there, ...
# 2020-11-29 23:05:40    Had a great morning at BWW, with my son eating...
# ...

# %%
for code, name in codes_names.items():
    collect_company_tweets(api, name, 
                           save_path="F:/Graduate/Lecture Notes and Homework/NLP")
# Out:
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   after removing the cwd from sys.path.
# 2020-12-09 07:30:58
# 2020-12-09 07:26:57
# 2020-12-09 06:53:58
# 2020-12-09 06:53:04
# 2020-12-09 06:50:56
# 2020-12-09 06:50:21
# 2020-12-09 06:49:13
# 2020-12-09 06:48:01
# 2020-12-09 06:47:12
# 2020-12-09 06:46:40
# 2020-12-09 06:45:59
# 2020-12-09 06:41:12
# 2020-12-09 04:29:54
# 2020-12-09 04:29:12
# 2020-12-09 03:44:37
# 2020-12-09 03:05:10
# 2020-12-09 02:54:46
# 2020-12-09 01:43:52
# 2020-12-09 00:53:10
# 2020-12-08 22:19:03
# 2020-12-08 21:52:48
# 2020-12-08 21:52:45
# 2020-12-08 20:29:46
# 2020-12-08 20:21:09
# 2020-12-08 20:19:42
# 2020-12-08 20:15:29
# 2020-12-08 20:07:25
# 2020-12-08 20:06:48
# 2020-12-08 19:25:52
# 2020-12-08 19:22:41
# 2020-12-08 19:11:07
# 2020-12-08 19:07:41
# 2020-12-08 18:33:02
# ...
